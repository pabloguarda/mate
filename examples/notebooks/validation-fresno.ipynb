# %% [markdown]
# ## Setup

# %%
import sys
import os
from pathlib import Path
import matplotlib.pyplot as plt
from datetime import datetime
import ast

import numpy as np
import pandas as pd
import geopandas as gpd
import contextily as ctx
import random
import isuelogit as isl
import glob
import time

from sklearn import preprocessing
from sklearn.impute import SimpleImputer

import tensorflow as tf
tf.config.set_visible_devices([], 'GPU')

# %%
# Path management
main_dir = str(Path(os.path.abspath("")).parents[1])
os.chdir(main_dir)
print('main dir:', main_dir)

sys.path.append(os.path.join(main_dir, 'src'))

# Folder that contains information of reference O-D matrix/pairs and paths.
isl.config.dirs['read_network_data'] = "input/network-data/fresno/"
# Out:
# main dir: /Users/pablo/github/mate

# %%
# %load_ext autoreload
# %autoreload 2

from pesuelogit.networks import read_OD, load_k_shortest_paths
from pesuelogit.etl import add_period_id

# Internal modules
from mate.models import compute_generated_trips, compute_generation_factors, \
    create_mate_model_fresno, compute_baseline_predictions_kfold, train_kfold
from mate.etl import build_network, get_tensors_by_year, data_curation
from mate.visualizations import plot_flow_vs_traveltime, plot_congestion_maps, \
    plot_metrics_kfold, plot_parameters_kfold, plot_baselines_kfold
from mate.metrics import mse, mape, r2_score,  z2score, mdape
from mate.utils import read_paths, flat_od_from_generated_trips

# %%
# Seed for reproducibility
_SEED = 2024
np.random.seed(_SEED)
random.seed(_SEED)
tf.random.set_seed(_SEED)

# %%
# To report global runtime
t0_global = time.time()

# %%
# Set timestamp to add in the filenames that are written in disk
ts = datetime.now().strftime('%y%m%d%H%M%S')
print('Timestamp:',ts)
# Out:
# Timestamp: 240127231842

# %% [markdown]
# ### Hyperparameters and configurations

# %%
# Data
_DAYSOFWEEK = [1,2,3]
_HOURS = np.arange(6,21) # _HOURS = [6,7,8, 15,16,17]

# Optimization
_LR = {'MaTE': {'learning': 5e-2, 'equilibrium': 5e-2, 'generation': 10}}
_RELATIVE_GAP = float('inf') # 1e-2 #
_BATCH_SIZE = 1
_LOSS_METRIC  = z2score
_OPTIMIZERS = {model: {key: tf.keras.optimizers.legacy.Adam(learning_rate=lr)
                       for key, lr in lrs.items()} for model, lrs in _LR.items()}
# Evaluation metric reported during model training
_EVALUATION_METRIC = mdape

# Exogenous attributes in utility function
_FEATURES_Z = ['tt_sd', 'median_inc', 'incidents', 'bus_stops', 'intersections']

# Number of splits, epochs and loss weights for k-fold cross-validation
_N_SPLITS = 5
_EPOCHS_KFOLD = {'MaTE':{'learning': 20, 'equilibrium': 0}}
_LOSS_WEIGHTS_KFOLD = {'MaTE': {'od': 0, 'traveltime': 1, 'flow': 1, 'equilibrium': 1}}

# Filepath of pretrained model that will be used for traffic forecasting
model_filepaths = {'MaTE':f'output/models/{240127164824}_fresno_mate.h5'}

# Numeric type of tensors
_DTYPE = tf.float32

# %% [markdown]
# ## Read nodes and link-specific data

# %%
nodes_df = pd.read_csv('./input/network-data/fresno/nodes/fresno-nodes-gis-data.csv')

links_df = pd.read_csv('./input/network-data/fresno/links/fresno-link-specific-data.csv',
                       converters={"link_key": ast.literal_eval, "pems_id": ast.literal_eval})

# %% [markdown]
# ## Build network

# %%
network = build_network(links_df=links_df, nodes_df=nodes_df, crs='epsg:4326', key= 'fresno')

# %%
## Display network
fig, ax = plt.subplots(figsize=(10, 10))
links_gdf = gpd.read_file('./input/network-data/fresno/gis/links/fresno-links-gis.shp').set_crs(
        'EPSG:2228')
links_gdf.to_crs(epsg=3857).plot(ax = ax)
ctx.add_basemap(ax = ax, source=ctx.providers.OpenStreetMap.Mapnik)

# %% [markdown]
# ## Read and load OD matrix

# %%
read_OD(network=network, sparse=True)
# Out:
# Matrix Q (1789, 1789) read in 0.0[s] with sparse format
# 66266.3 trips were loaded among 6970 o-d pairs

# %% [markdown]
# ## Read and load paths

# %%
read_paths(network=network, update_incidence_matrices=True, filename = 'paths-fresno-k3.csv')
# read_paths(network=network, update_incidence_matrices=True, filename = 'paths-full-model-fresno.csv')
# Out:
# 20840 paths were read and incidence matrices were built

# %% [markdown]
# ## Read and process spatio-temporal link-level data

# %%
folderpath = './input/network-data/fresno/links/spatiotemporal-data/'
df = pd.concat([pd.read_csv(file) for file in glob.glob(folderpath + "*link-data*")], axis=0)

df['date'] = pd.to_datetime(df['date'], format='%Y-%m-%d')
df['year'] = df.date.dt.year
df['link_key'] = pd.Categorical(df['link_key'].apply(ast.literal_eval), list(network.links_dict.keys()))
df['period'] = pd.to_datetime(df['period'], format = '%Y-%m-%d-%H').dt.strftime('%Y-%m-%d-%H')

# Select data from Tuesdays to Thursdays
df = df[df['date'].dt.dayofweek.isin(_DAYSOFWEEK)]

# # Select data from first Tuesdays of 2019 and 2020
# df = df[df['date'].isin(["2019-10-01", "2020-10-06"])]

# # Select countdata from selected links
# selected_links = [(290,169,'0'),(170,168,'0'),(337,692,'0'),(228,192,'0'),(191,171,'0'),(188,87,'0'), (171,290,'0'),(192,191,'0'),(87,228,'0'),(169,332,'0'),(631,635,'0'),(179,183,'0'), (641,86,'0'),(638,634,'0'),(170,207,'0'),(86,189,'0'),(580,142,'0'),(333,332,'0'), (99,43,'0'),(637,639,'0')]
# df.loc[~df.link_key.isin(selected_links),'counts'] = float('nan')

# %%
# Add period id for timevarying estimation
period_feature = 'hour'

df = add_period_id(df, period_feature='hour')

period_keys = df[[period_feature,'period_id']].drop_duplicates().reset_index().drop('index',axis =1).sort_values('hour')
print(period_keys)
# Out:
#     hour  period_id
# 11     6          0
# 12     7          1
# 13     8          2
# 14     9          3
# 0     10          4
# 1     11          5
# 2     12          6
# 3     13          7
# 4     14          8
# 5     15          9
# 6     16         10
# 7     17         11
# 8     18         12
# 9     19         13
# 10    20         14

# %%
# Curation of travel time and link flow related features
df = data_curation(df)

# %%
# Units of travel time features are converted from hours to minutes
df['tt_sd'] = df['tt_sd']*60
df['tt_avg'] = df['tt_avg']*60
df['tt_ff'] = df['tt_ff']*60

# %%
# Set free flow travel times
tt_ff_links = df.groupby('link_key')['tt_ff'].min()
for link in network.links:
    network.links_dict[link.key].performance_function.tf = float(tt_ff_links[tt_ff_links.index==link.key].iloc[0])

# Set capacity in links considering number of lanes
capacity_links = df.groupby('link_key')['capacity'].mean()
for link in network.links:
    network.links_dict[link.key].performance_function.k = float(capacity_links[capacity_links.index==link.key].iloc[0])

# %% [markdown]
# ## Process node-level data

# %%
nodes_df = nodes_df.rename(columns ={'pop_tract':'population','stops_tract': 'bus_stops','median_inc':'income'})

features_generation = ['population','income', 'bus_stops']

nodes_df = nodes_df[['key','type'] + features_generation]

imp_mean = SimpleImputer(missing_values=np.nan, strategy='mean')
imp_mean.fit(nodes_df[features_generation])
nodes_df[features_generation] = imp_mean.transform(nodes_df[features_generation])

scaler = preprocessing.StandardScaler().fit(nodes_df[features_generation].values)
nodes_df[features_generation] = scaler.transform(nodes_df[features_generation].values)

# %% [markdown]
# ## Exploratory Data Analysis

# %%
# Stats by date
print(df.groupby('date')[['speed_sd','speed_avg', 'counts_lane']].mean().assign(total_obs = df.groupby('date')['hour'].count()))
# Out:
#             speed_sd  speed_avg  counts_lane  total_obs
# date
# 2019-10-01  1.731787  17.175187  1497.588808      36195
# 2019-10-02  1.760109  17.169768  1476.571607      36195
# 2019-10-03  1.754288  17.092304  1509.584533      36195
# 2019-10-08  1.847060  18.165569  1478.300459      36195
# 2019-10-09  1.917923  18.137042  1481.272743      36195
# 2019-10-10  1.830232  18.107925  1514.981758      36195
# 2019-10-15  1.831527  18.114384  1480.838248      36195
# 2019-10-16  1.823680  18.162625  1486.702565      36195
# 2019-10-17  1.832219  18.080860  1501.029287      36195
# 2019-10-22  1.837839  18.175561  1470.843410      36195
# 2019-10-23  1.864443  18.222690  1478.096704      36195
# 2019-10-24  1.848827  18.184814  1474.877009      36195
# 2019-10-29  1.868430  18.167171  1465.606342      36195
# 2019-10-30  1.816364  18.109232  1490.846582      36195
# 2019-10-31  1.882446  18.128430  1524.102867      36195
# 2020-10-01  1.290377  19.579215  1359.944262      36195
# 2020-10-06  1.365919  19.709670  1331.870352      36195
# 2020-10-07  1.327017  19.927088  1334.612549      36195
# 2020-10-08  1.344382  19.969943  1349.797144      36195
# 2020-10-13  1.311842  19.626350  1355.705338      36195
# 2020-10-14  1.300075  19.558364  1358.068966      36195
# 2020-10-15  1.331493  19.621633  1378.649462      36195
# 2020-10-20  1.353743  19.597736  1345.194608      36195
# 2020-10-21  1.325694  19.501768  1337.546170      36195
# 2020-10-22  1.334320  19.591921  1370.720073      36195
# 2020-10-27  1.309348  19.573460  1336.894292      36195
# 2020-10-28  1.324270  19.646064  1342.285896      36195
# 2020-10-29  1.336212  19.557279  1370.069862      36195

# %%
## Link-level attributes in utility function
df[_FEATURES_Z].describe()
# Out:
#               tt_sd    median_inc     incidents     bus_stops  intersections
# count  1.013460e+06  1.013460e+06  1.013460e+06  1.013460e+06   1.013460e+06
# mean   1.813680e-02  2.621913e+01  7.441093e-01  1.500207e-01   8.765023e-01
# std    2.783112e-02  2.135738e+01  3.193143e+00  4.411927e-01   1.319496e+00
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00   0.000000e+00
# 25%    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00   0.000000e+00
# 50%    1.113761e-02  2.482100e+01  0.000000e+00  0.000000e+00   0.000000e+00
# 75%    2.548870e-02  4.168100e+01  0.000000e+00  0.000000e+00   1.000000e+00
# max    7.459602e-01  1.158930e+02  4.000000e+01  4.000000e+00   9.000000e+00

# %% [markdown]
# ## Training and validation sets

# %%
# Hourly data
XT, YT = get_tensors_by_year(df[df.hour.isin(_HOURS)], features_Z = _FEATURES_Z, links_keys=list(network.links_dict.keys()))

# Split in training and test sets
XT_train, XT_val, YT_train, YT_val = map(lambda x: tf.cast(x, dtype = _DTYPE), [XT[2019], XT[2020], YT[2019], YT[2020]])

n_periods = len(np.unique(XT_train[:, :, -1].numpy().flatten()))

# %% [markdown]
# ### Reference O-D matrix and trip generation vectors

# %%
q_historic = np.repeat(network.q.flatten()[np.newaxis, :], len(_HOURS), axis=0)

#Adjust historic O-D and historic trip generation
generation_factors = compute_generation_factors(period_column=XT_train[:, :, -1, None].numpy(),
                                                              flow_column=YT_train[:,:,1, None].numpy(), reference_period=10)

reference_q = q_historic*np.tile(generation_factors.values,(q_historic.shape[1],1)).T

reference_g = compute_generated_trips(q = reference_q, ods= network.ods, n_nodes = len(network.nodes))

# %% [markdown]
# ## Models

# %%
train_results_dfs = {}
val_results_dfs = {}
models = {}
inference_models = {}

# %% [markdown]
# # Forecasting

# %%
# Create model for inference (make sure that the arguments are the same than those used to create the reference model)
inference_models['MaTE'] = create_mate_model_fresno(network = network, n_periods = n_periods, features_Z = _FEATURES_Z,
                                                                reference_g = reference_g, dtype = _DTYPE)
inference_models['MaTE'].build()

inference_models['MaTE'].load_weights(model_filepaths['MaTE'])

# %% [markdown]
# ### - Model estimated with all data from 2019

# %%
# This should convergence immediately when the data for prediction is equal to training set
_ = inference_models['MaTE'].predict(XT_train,
                                           # period_dict = reference_model.period_dict,
                                           node_data=nodes_df,
                                           loss_metric=_LOSS_METRIC,
                                           pretrain_link_flows = False,
                                           # batch_size= _BATCH_SIZE,
                                           optimizer= _OPTIMIZERS['MaTE']['equilibrium'],
                                           loss_weights={'equilibrium': 1},
                                           threshold_relative_gap=_RELATIVE_GAP,
                                           epochs=100)
# Out:
# Computing gradient based equilibrium
#
# Model training
#
# hyperparameters loss function: {'equilibrium': 1}
#
# number of periods: 15, batch size: 225, threshold relative gap: inf
# training set -> timepoints: 225, obs [t x]: nan, coverage [t x]: nan
#
# 0/100: train mse=1.5e+04, avg theta = [-3.951 -3.635  0.    -3.668 -0.199 -4.266], avg rr = 0.92, avg theta fixed effect = 0.041, loss prop od=0, total trips=[6.15e+04 6.95e+04 6.07e+04 5.97e+04 7.28e+04 7.86e+04 7.61e+04 8.02e+04
#  8.90e+04 9.36e+04 9.73e+04 9.43e+04 8.62e+04 7.75e+04 6.76e+04], polynomial weights: [2.0e-01 1.4e-02 1.2e-02], kappa = [108.003  23.238 -31.658], lambda eq=1, relative gap=0.047, train equilibrium loss=1.5e+04, time: 2.9
#
# Relative gap threshold of inf was achieved in equilibrium stage

# %%
with pd.option_context('display.float_format', '{:0.3g}'.format):
    print('\n')
    training_metrics = inference_models['MaTE'].compute_loss_metrics(
        metrics={_EVALUATION_METRIC.__name__: _EVALUATION_METRIC, 'mse': mse, 'mape': mape, 'r2': r2_score},
        X=XT_train, Y=YT_train)
    print(training_metrics)

# model.summary()
# Out:
#      component    value metric
# 0         flow     17.5  mdape
# 1   traveltime     4.67  mdape
# 2  equilibrium     4.58  mdape
# 0         flow 9.46e+05    mse
# 1   traveltime  0.00281    mse
# 2  equilibrium 1.47e+04    mse
# 0         flow     51.1   mape
# 1   traveltime     7.29   mape
# 2  equilibrium 9.57e+13   mape
# 0         flow     0.77     r2
# 1   traveltime     0.96     r2
# 2  equilibrium    0.993     r2

# %%
fig, axs = plot_flow_vs_traveltime(model = inference_models['MaTE'],
                        observed_traveltime=inference_models['MaTE'].mask_observed_traveltime(YT_train[:, :, 0]),
                        observed_flow= inference_models['MaTE'].mask_observed_flow(YT_train[:,:,1]),
                        period_col = pd.DataFrame({'period': list(XT_train[:, :, -1].numpy().astype(int).flatten())})['period'].
                                   map(dict(zip(period_keys.period_id, period_keys.hour))).values.flatten(),
                        hour_label=True,
                        all_metrics = False
                        )

plt.savefig('output/figures/results/fresno-scatter-flow-traveltime-mate-2019.png', dpi = 300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ### -Make prediction on 2020, the validation set

# %%
# Create model for inference (make sure that the arguments are the same than those used to create the reference model)
inference_models['mate-2020'] = create_mate_model_fresno(network = network, n_periods = n_periods, features_Z = _FEATURES_Z,
                                                                reference_g = reference_g, dtype = _DTYPE)
inference_models['mate-2020'].build()

inference_models['mate-2020'].load_weights(model_filepaths['MaTE'])

# %%
_ = inference_models['mate-2020'].predict(XT_val,
                                           node_data=nodes_df,
                                           loss_metric=_LOSS_METRIC,
                                           # batch_size= _BATCH_SIZE,
                                           optimizer= _OPTIMIZERS['MaTE']['equilibrium'],
                                           pretrain_link_flows = False,
                                           loss_weights={'equilibrium': 1},
                                           threshold_relative_gap= inference_models['MaTE'].compute_relative_gap(),
                                           epochs=100)
# Out:
# Computing gradient based equilibrium
#
# Model training
#
# hyperparameters loss function: {'equilibrium': 1}
#
# number of periods: 15, batch size: 195, threshold relative gap: 0.04734824597835541
# training set -> timepoints: 195, obs [t x]: nan, coverage [t x]: nan
#
# 0/100: train mse=3.8e+04, avg theta = [-3.951 -3.635  0.    -3.668 -0.199 -4.266], avg rr = 0.92, avg theta fixed effect = 0.041, loss prop od=0, total trips=[6.15e+04 6.95e+04 6.07e+04 5.97e+04 7.28e+04 7.86e+04 7.61e+04 8.02e+04
#  8.90e+04 9.36e+04 9.73e+04 9.43e+04 8.62e+04 7.75e+04 6.76e+04], polynomial weights: [2.0e-01 1.4e-02 1.2e-02], kappa = [108.003  23.238 -31.658], lambda eq=1, relative gap=0.062, train equilibrium loss=3.8e+04, time: 2.8
#
# 1/100: train mse=3.7e+04, avg theta = [-3.951 -3.635  0.    -3.668 -0.199 -4.266], avg rr = 0.92, avg theta fixed effect = 0.041, loss prop od=0, total trips=[6.15e+04 6.95e+04 6.07e+04 5.97e+04 7.28e+04 7.86e+04 7.61e+04 8.02e+04
#  8.90e+04 9.36e+04 9.73e+04 9.43e+04 8.62e+04 7.75e+04 6.76e+04], polynomial weights: [2.0e-01 1.4e-02 1.2e-02], kappa = [108.003  23.238 -31.658], lambda eq=1, relative gap=0.06, train equilibrium loss=3.7e+04, time: 10.4
#
# 2/100: train mse=3.7e+04, avg theta = [-3.951 -3.635  0.    -3.668 -0.199 -4.266], avg rr = 0.92, avg theta fixed effect = 0.041, loss prop od=0, total trips=[6.15e+04 6.95e+04 6.07e+04 5.97e+04 7.28e+04 7.86e+04 7.61e+04 8.02e+04
#  8.90e+04 9.36e+04 9.73e+04 9.43e+04 8.62e+04 7.75e+04 6.76e+04], polynomial weights: [2.0e-01 1.4e-02 1.2e-02], kappa = [108.003  23.238 -31.658], lambda eq=1, relative gap=0.058, train equilibrium loss=3.7e+04, time: 10.0
#
# 3/100: train mse=3.6e+04, avg theta = [-3.951 -3.635  0.    -3.668 -0.199 -4.266], avg rr = 0.92, avg theta fixed effect = 0.041, loss prop od=0, total trips=[6.15e+04 6.95e+04 6.07e+04 5.97e+04 7.28e+04 7.86e+04 7.61e+04 8.02e+04
#  8.90e+04 9.36e+04 9.73e+04 9.43e+04 8.62e+04 7.75e+04 6.76e+04], polynomial weights: [2.0e-01 1.4e-02 1.2e-02], kappa = [108.003  23.238 -31.658], lambda eq=1, relative gap=0.055, train equilibrium loss=3.6e+04, time: 9.3
#
# 4/100: train mse=3.5e+04, avg theta = [-3.951 -3.635  0.    -3.668 -0.199 -4.266], avg rr = 0.92, avg theta fixed effect = 0.041, loss prop od=0, total trips=[6.15e+04 6.95e+04 6.07e+04 5.97e+04 7.28e+04 7.86e+04 7.61e+04 8.02e+04
#  8.90e+04 9.36e+04 9.73e+04 9.43e+04 8.62e+04 7.75e+04 6.76e+04], polynomial weights: [2.0e-01 1.4e-02 1.2e-02], kappa = [108.003  23.238 -31.658], lambda eq=1, relative gap=0.053, train equilibrium loss=3.5e+04, time: 9.0
#
# 5/100: train mse=3.5e+04, avg theta = [-3.951 -3.635  0.    -3.668 -0.199 -4.266], avg rr = 0.92, avg theta fixed effect = 0.041, loss prop od=0, total trips=[6.15e+04 6.95e+04 6.07e+04 5.97e+04 7.28e+04 7.86e+04 7.61e+04 8.02e+04
#  8.90e+04 9.36e+04 9.73e+04 9.43e+04 8.62e+04 7.75e+04 6.76e+04], polynomial weights: [2.0e-01 1.4e-02 1.2e-02], kappa = [108.003  23.238 -31.658], lambda eq=1, relative gap=0.052, train equilibrium loss=3.5e+04, time: 10.1
#
# 6/100: train mse=3.4e+04, avg theta = [-3.951 -3.635  0.    -3.668 -0.199 -4.266], avg rr = 0.92, avg theta fixed effect = 0.041, loss prop od=0, total trips=[6.15e+04 6.95e+04 6.07e+04 5.97e+04 7.28e+04 7.86e+04 7.61e+04 8.02e+04
#  8.90e+04 9.36e+04 9.73e+04 9.43e+04 8.62e+04 7.75e+04 6.76e+04], polynomial weights: [2.0e-01 1.4e-02 1.2e-02], kappa = [108.003  23.238 -31.658], lambda eq=1, relative gap=0.05, train equilibrium loss=3.4e+04, time: 9.0
#
# 7/100: train mse=3.4e+04, avg theta = [-3.951 -3.635  0.    -3.668 -0.199 -4.266], avg rr = 0.92, avg theta fixed effect = 0.041, loss prop od=0, total trips=[6.15e+04 6.95e+04 6.07e+04 5.97e+04 7.28e+04 7.86e+04 7.61e+04 8.02e+04
#  8.90e+04 9.36e+04 9.73e+04 9.43e+04 8.62e+04 7.75e+04 6.76e+04], polynomial weights: [2.0e-01 1.4e-02 1.2e-02], kappa = [108.003  23.238 -31.658], lambda eq=1, relative gap=0.048, train equilibrium loss=3.4e+04, time: 10.0
#
# 8/100: train mse=3.3e+04, avg theta = [-3.951 -3.635  0.    -3.668 -0.199 -4.266], avg rr = 0.92, avg theta fixed effect = 0.041, loss prop od=0, total trips=[6.15e+04 6.95e+04 6.07e+04 5.97e+04 7.28e+04 7.86e+04 7.61e+04 8.02e+04
#  8.90e+04 9.36e+04 9.73e+04 9.43e+04 8.62e+04 7.75e+04 6.76e+04], polynomial weights: [2.0e-01 1.4e-02 1.2e-02], kappa = [108.003  23.238 -31.658], lambda eq=1, relative gap=0.047, train equilibrium loss=3.3e+04, time: 9.5
#
# Relative gap threshold of 0.04734824597835541 was achieved in equilibrium stage

# %%
with pd.option_context('display.float_format', '{:0.3g}'.format):
    print('\n')
    validation_metrics = inference_models['MaTE'].compute_loss_metrics(
        metrics = {_EVALUATION_METRIC.__name__: _EVALUATION_METRIC, 'mse': mse, 'mape': mape, 'r2': r2_score},
        X = XT_val, Y = YT_val)
    print(validation_metrics)
# Out:
#      component    value metric
# 0         flow       22  mdape
# 1   traveltime     6.85  mdape
# 2  equilibrium     5.13  mdape
# 0         flow 1.28e+06    mse
# 1   traveltime  0.00485    mse
# 2  equilibrium 3.77e+04    mse
# 0         flow       39   mape
# 1   traveltime     10.7   mape
# 2  equilibrium 2.81e+16   mape
# 0         flow    0.635     r2
# 1   traveltime    0.924     r2
# 2  equilibrium    0.982     r2

# %%
fig, axs = plot_flow_vs_traveltime(model = inference_models['MaTE'],
                        observed_traveltime=inference_models['MaTE'].mask_observed_traveltime(YT_val[:, :, 0]),
                        observed_flow= inference_models['MaTE'].mask_observed_flow(YT_val[:,:,1]),
                        # scatter_kws={"color": sns.color_palette("deep")[0], 's':4, 'alpha': 1}, line_kws={"color": "black"},
                        period_col = pd.DataFrame({'period': list(XT_val[:, :, -1].numpy().astype(int).flatten())})['period'].
                                   map(dict(zip(period_keys.period_id, period_keys.hour))).values.flatten(),
                        hour_label=True,
                        all_metrics = False
                        )

plt.savefig('output/figures/results/fresno-scatter-flow-traveltime-mate-2020.png', dpi = 300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## K-Fold Cross Validation

# %%
models_kfold = {}
metrics_kfold_df = {}
parameters_kfold_df = {}

# %%
models_kfold['MaTE'] = create_mate_model_fresno(network = network, n_periods = n_periods, features_Z = _FEATURES_Z, reference_g = reference_g)
models_kfold['MaTE'].build()

# # Use pretrained weights
# models_kfold['MaTE'].load_weights(model_filepaths['MaTE'])
# models_kfold['MaTE'].generation._pretrain_generation_weights = False

# Assumed there is access to reference OD matrix
# q_reference = models_kfold['MaTE'].q

# Add historic OD from estimation in 2019
# models_kfold['MaTE'].od.reference_values = q_reference

# %%
metrics_kfold_df['MaTE'], parameters_kfold_df['MaTE'] = train_kfold(
    n_splits=_N_SPLITS ,
    random_state = _SEED,
    model = models_kfold['MaTE'],
    X = XT_val, Y = YT_val,
    optimizers= _OPTIMIZERS['MaTE'],
    node_data = nodes_df,
    loss_weights=_LOSS_WEIGHTS_KFOLD['MaTE'],
    loss_metric=_LOSS_METRIC,
    evaluation_metric=_EVALUATION_METRIC,
    epochs_print_interval= _EPOCHS_KFOLD['MaTE'].copy(),
    threshold_relative_gap= _RELATIVE_GAP,
    batch_size=_BATCH_SIZE,
    epochs = _EPOCHS_KFOLD['MaTE'],
)
# Out:
# 2024-01-27 23:22:02.655596: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# Fold 1/5
#
# Model training
#
# Pretraining generation weights
#
# period 0 -> p-values kappa: {'population': 0.0017, 'income': 0.5592, 'bus_stops': 0.341}
# period 1 -> p-values kappa: {'population': 0.0017, 'income': 0.5592, 'bus_stops': 0.341}
# period 2 -> p-values kappa: {'population': 0.0017, 'income': 0.5592, 'bus_stops': 0.341}
# period 3 -> p-values kappa: {'population': 0.0017, 'income': 0.5592, 'bus_stops': 0.341}
# period 4 -> p-values kappa: {'population': 0.0017, 'income': 0.5592, 'bus_stops': 0.341}
# period 5 -> p-values kappa: {'population': 0.0017, 'income': 0.5592, 'bus_stops': 0.341}
# period 6 -> p-values kappa: {'population': 0.0017, 'income': 0.5592, 'bus_stops': 0.341}
# period 7 -> p-values kappa: {'population': 0.0017, 'income': 0.5592, 'bus_stops': 0.341}
# period 8 -> p-values kappa: {'population': 0.0017, 'income': 0.5592, 'bus_stops': 0.341}
# period 9 -> p-values kappa: {'population': 0.0017, 'income': 0.5592, 'bus_stops': 0.341}
# period 10 -> p-values kappa: {'population': 0.0017, 'income': 0.5592, 'bus_stops': 0.341}
# period 11 -> p-values kappa: {'population': 0.0017, 'income': 0.5592, 'bus_stops': 0.341}
# period 12 -> p-values kappa: {'population': 0.0017, 'income': 0.5592, 'bus_stops': 0.341}
# period 13 -> p-values kappa: {'population': 0.0017, 'income': 0.5592, 'bus_stops': 0.341}
# period 14 -> p-values kappa: {'population': 0.0017, 'income': 0.5592, 'bus_stops': 0.341}
#
# Link flows and travel times were pretrained with single pass of traffic assignment
# Benchmark metrics using historical mean in training data to make predictions in the validation set:
#
#
#     component    value metric
# 0        flow       40  mdape
# 1  traveltime       52  mdape
# 0        flow    3e+06    mse
# 1  traveltime     0.05    mse
# 0        flow    1e+02   mape
# 1  traveltime       82   mape
# 0        flow   -0.026     r2
# 1  traveltime -0.00011     r2
#
# hyperparameters loss function: {'od': 0, 'traveltime': 1, 'flow': 1, 'equilibrium': 1}
#
# number of periods: 15, batch size: 1, threshold relative gap: inf
# training set -> timepoints: 195, obs [t x]: [1153.  112.], coverage [t x]: [0.478 0.046]
# validation set -> timepoints: 195, obs [t x]: [302.  28.], coverage [t x]: [0.125 0.012]
#
# Learning stage: 20 epochs
#
# 0/20: train mse=2e+06, train mse traveltime=0.077, train mdape traveltime=14.7 train mse flow=5.9e+06, train mdape flow=52.2, val mse=1.4e+06, val mse traveltime=0.13, val mdape traveltime=15.2 val mse flow=4.2e+06, val mdape flow=49.6, avg theta = [-3.06  -3.268  0.    -4.537  0.    -3.879], avg rr = 1.07, avg theta fixed effect = 0, loss prop od=0, total trips=[5.47e+04 6.30e+04 5.51e+04 4.96e+04 4.98e+04 5.23e+04 5.48e+04 5.82e+04
#  6.32e+04 6.65e+04 6.63e+04 5.86e+04 4.59e+04 3.63e+04 3.04e+04], polynomial weights: [1.0e+00 1.0e+00 1.0e+00], kappa = [108.003  23.238 -31.658], lambda eq=1, relative gap=0.025, train equilibrium loss=3.1e+04, val equilibrium loss=3.1e+04, time: 2.9
#
# 1/20: train mse=1.1e+06, train mse traveltime=0.0032, train mdape traveltime=7.0 train mse flow=2.9e+06, train mdape flow=33.1, val mse=1.1e+06, val mse traveltime=0.11, val mdape traveltime=13.6 val mse flow=3e+06, val mdape flow=35.3, avg theta = [-3.677 -3.76   0.    -3.938 -0.06  -4.059], avg rr = 1.02, avg theta fixed effect = -0.014, loss prop od=0, total trips=[5.79e+04 6.39e+04 5.64e+04 5.31e+04 5.62e+04 5.97e+04 6.64e+04 6.39e+04
#  6.87e+04 7.45e+04 7.54e+04 6.86e+04 5.34e+04 4.59e+04 3.29e+04], polynomial weights: [3.8e-01 3.5e-01 4.5e-01], kappa = [108.003  23.238 -31.658], lambda eq=1, relative gap=0.3, train equilibrium loss=2.8e+05, val equilibrium loss=2.8e+05, time: 552.7
#
# 20/20: train mse=2.2e+05, train mse traveltime=0.0016, train mdape traveltime=4.3 train mse flow=6.4e+05, train mdape flow=13.4, val mse=7.5e+05, val mse traveltime=0.023, val mdape traveltime=11.7 val mse flow=2.2e+06, val mdape flow=38.2, avg theta = [-3.998 -3.668  0.    -3.282 -0.079 -4.38 ], avg rr = 0.92, avg theta fixed effect = -0.052, loss prop od=0, total trips=[6.38e+04 6.75e+04 5.97e+04 5.99e+04 7.08e+04 7.76e+04 7.64e+04 8.10e+04
#  8.71e+04 9.61e+04 9.39e+04 9.02e+04 7.82e+04 7.26e+04 6.33e+04], polynomial weights: [1.1e-01 5.1e-02 7.8e-02], kappa = [108.003  23.238 -31.658], lambda eq=1, relative gap=0.047, train equilibrium loss=1.9e+04, val equilibrium loss=1.9e+04, time: 9655.8
#
# Relative gap threshold of inf was achieved in learning stage
#
# Fold 2/5
#
# Model training
#
# Pretraining generation weights
#
# period 0 -> p-values kappa: {'population': 0.0017, 'income': 0.5592, 'bus_stops': 0.341}
# period 1 -> p-values kappa: {'population': 0.0017, 'income': 0.5592, 'bus_stops': 0.341}
# period 2 -> p-values kappa: {'population': 0.0017, 'income': 0.5592, 'bus_stops': 0.341}
# period 3 -> p-values kappa: {'population': 0.0017, 'income': 0.5592, 'bus_stops': 0.341}
# period 4 -> p-values kappa: {'population': 0.0017, 'income': 0.5592, 'bus_stops': 0.341}
# period 5 -> p-values kappa: {'population': 0.0017, 'income': 0.5592, 'bus_stops': 0.341}
# period 6 -> p-values kappa: {'population': 0.0017, 'income': 0.5592, 'bus_stops': 0.341}
# period 7 -> p-values kappa: {'population': 0.0017, 'income': 0.5592, 'bus_stops': 0.341}
# period 8 -> p-values kappa: {'population': 0.0017, 'income': 0.5592, 'bus_stops': 0.341}
# period 9 -> p-values kappa: {'population': 0.0017, 'income': 0.5592, 'bus_stops': 0.341}
# period 10 -> p-values kappa: {'population': 0.0017, 'income': 0.5592, 'bus_stops': 0.341}
# period 11 -> p-values kappa: {'population': 0.0017, 'income': 0.5592, 'bus_stops': 0.341}
# period 12 -> p-values kappa: {'population': 0.0017, 'income': 0.5592, 'bus_stops': 0.341}
# period 13 -> p-values kappa: {'population': 0.0017, 'income': 0.5592, 'bus_stops': 0.341}
# period 14 -> p-values kappa: {'population': 0.0017, 'income': 0.5592, 'bus_stops': 0.341}
#
# Link flows and travel times were pretrained with single pass of traffic assignment
# Benchmark metrics using historical mean in training data to make predictions in the validation set:
#
#
#     component    value metric
# 0        flow       32  mdape
# 1  traveltime       50  mdape
# 0        flow  2.6e+06    mse
# 1  traveltime    0.095    mse
# 0        flow       68   mape
# 1  traveltime       77   mape
# 0        flow -0.00055     r2
# 1  traveltime  -0.0022     r2
#
# hyperparameters loss function: {'od': 0, 'traveltime': 1, 'flow': 1, 'equilibrium': 1.0}
#
# number of periods: 15, batch size: 1, threshold relative gap: inf
# training set -> timepoints: 195, obs [t x]: [1168.  112.], coverage [t x]: [0.484 0.047]
# validation set -> timepoints: 195, obs [t x]: [287.  28.], coverage [t x]: [0.119 0.012]
#
# Learning stage: 20 epochs
#
# 0/20: train mse=1.8e+06, train mse traveltime=0.1, train mdape traveltime=14.6 train mse flow=5.4e+06, train mdape flow=49.2, val mse=2.1e+06, val mse traveltime=0.035, val mdape traveltime=15.4 val mse flow=6.2e+06, val mdape flow=58.2, avg theta = [-3.06  -3.268  0.    -4.537  0.    -3.879], avg rr = 1.07, avg theta fixed effect = 0, loss prop od=0, total trips=[5.47e+04 6.30e+04 5.51e+04 4.96e+04 4.98e+04 5.23e+04 5.48e+04 5.82e+04
#  6.32e+04 6.65e+04 6.63e+04 5.86e+04 4.59e+04 3.63e+04 3.04e+04], polynomial weights: [1.0e+00 1.0e+00 1.0e+00], kappa = [108.003  23.238 -31.658], lambda eq=1, relative gap=0.025, train equilibrium loss=3.1e+04, val equilibrium loss=3.1e+04, time: 2.7
#
# 1/20: train mse=1e+06, train mse traveltime=0.0025, train mdape traveltime=7.0 train mse flow=2.8e+06, train mdape flow=26.9, val mse=1.6e+06, val mse traveltime=0.21, val mdape traveltime=14.7 val mse flow=4.7e+06, val mdape flow=56.5, avg theta = [-3.663 -3.704  0.014 -3.772 -0.064 -3.873], avg rr = 1.01, avg theta fixed effect = -0.0097, loss prop od=0, total trips=[5.61e+04 6.19e+04 5.55e+04 5.26e+04 5.33e+04 5.95e+04 6.10e+04 6.45e+04
#  6.89e+04 7.27e+04 7.62e+04 6.90e+04 5.56e+04 3.94e+04 3.73e+04], polynomial weights: [3.9e-01 2.4e-01 2.0e-01], kappa = [108.003  23.238 -31.658], lambda eq=1, relative gap=0.29, train equilibrium loss=2.3e+05, val equilibrium loss=2.3e+05, time: 497.3
#
# 20/20: train mse=2.3e+05, train mse traveltime=0.0012, train mdape traveltime=4.3 train mse flow=6.8e+05, train mdape flow=15.1, val mse=8.4e+05, val mse traveltime=0.18, val mdape traveltime=14.4 val mse flow=2.5e+06, val mdape flow=32.0, avg theta = [-3.63  -3.764  0.    -3.733  0.    -4.327], avg rr = 1.04, avg theta fixed effect = -0.036, loss prop od=0, total trips=[5.99e+04 6.06e+04 5.40e+04 5.61e+04 6.67e+04 6.97e+04 7.13e+04 7.54e+04
#  8.33e+04 9.01e+04 9.07e+04 8.96e+04 7.35e+04 6.73e+04 6.02e+04], polynomial weights: [3.2e-01 2.0e-01 5.6e-02], kappa = [108.003  23.238 -31.658], lambda eq=1, relative gap=0.057, train equilibrium loss=2.3e+04, val equilibrium loss=2.3e+04, time: 9222.9
#
# Relative gap threshold of inf was achieved in learning stage
#
# Fold 3/5
#
# Model training
#
# Pretraining generation weights
#
# period 0 -> p-values kappa: {'population': 0.0017, 'income': 0.5592, 'bus_stops': 0.341}
# period 1 -> p-values kappa: {'population': 0.0017, 'income': 0.5592, 'bus_stops': 0.341}
# period 2 -> p-values kappa: {'population': 0.0017, 'income': 0.5592, 'bus_stops': 0.341}
# period 3 -> p-values kappa: {'population': 0.0017, 'income': 0.5592, 'bus_stops': 0.341}
# period 4 -> p-values kappa: {'population': 0.0017, 'income': 0.5592, 'bus_stops': 0.341}
# period 5 -> p-values kappa: {'population': 0.0017, 'income': 0.5592, 'bus_stops': 0.341}
# period 6 -> p-values kappa: {'population': 0.0017, 'income': 0.5592, 'bus_stops': 0.341}
# period 7 -> p-values kappa: {'population': 0.0017, 'income': 0.5592, 'bus_stops': 0.341}
# period 8 -> p-values kappa: {'population': 0.0017, 'income': 0.5592, 'bus_stops': 0.341}
# period 9 -> p-values kappa: {'population': 0.0017, 'income': 0.5592, 'bus_stops': 0.341}
# period 10 -> p-values kappa: {'population': 0.0017, 'income': 0.5592, 'bus_stops': 0.341}
# period 11 -> p-values kappa: {'population': 0.0017, 'income': 0.5592, 'bus_stops': 0.341}
# period 12 -> p-values kappa: {'population': 0.0017, 'income': 0.5592, 'bus_stops': 0.341}
# period 13 -> p-values kappa: {'population': 0.0017, 'income': 0.5592, 'bus_stops': 0.341}
# period 14 -> p-values kappa: {'population': 0.0017, 'income': 0.5592, 'bus_stops': 0.341}
#
# Link flows and travel times were pretrained with single pass of traffic assignment
# Benchmark metrics using historical mean in training data to make predictions in the validation set:
#
#
#     component   value metric
# 0        flow      35  mdape
# 1  traveltime      52  mdape
# 0        flow 3.3e+06    mse
# 1  traveltime   0.055    mse
# 0        flow      47   mape
# 1  traveltime      88   mape
# 0        flow   -0.17     r2
# 1  traveltime  -0.006     r2
#
# hyperparameters loss function: {'od': 0, 'traveltime': 1, 'flow': 1, 'equilibrium': 1.0}
#
# number of periods: 15, batch size: 1, threshold relative gap: inf
# training set -> timepoints: 195, obs [t x]: [1155.  112.], coverage [t x]: [0.479 0.047]
# validation set -> timepoints: 195, obs [t x]: [299.  28.], coverage [t x]: [0.124 0.012]
#
# Learning stage: 20 epochs
#
# 0/20: train mse=1.9e+06, train mse traveltime=0.085, train mdape traveltime=15.0 train mse flow=5.5e+06, train mdape flow=53.4, val mse=1.9e+06, val mse traveltime=0.1, val mdape traveltime=14.0 val mse flow=5.7e+06, val mdape flow=44.2, avg theta = [-3.06  -3.268  0.    -4.537  0.    -3.879], avg rr = 1.07, avg theta fixed effect = 0, loss prop od=0, total trips=[5.47e+04 6.30e+04 5.51e+04 4.96e+04 4.98e+04 5.23e+04 5.48e+04 5.82e+04
#  6.32e+04 6.65e+04 6.63e+04 5.86e+04 4.59e+04 3.63e+04 3.04e+04], polynomial weights: [1.0e+00 1.0e+00 1.0e+00], kappa = [108.003  23.238 -31.658], lambda eq=1, relative gap=0.025, train equilibrium loss=3.1e+04, val equilibrium loss=3.1e+04, time: 2.8
#
# 1/20: train mse=1.1e+06, train mse traveltime=0.0033, train mdape traveltime=7.1 train mse flow=3.1e+06, train mdape flow=34.5, val mse=1.2e+06, val mse traveltime=0.18, val mdape traveltime=14.3 val mse flow=3.4e+06, val mdape flow=27.1, avg theta = [-3.314 -3.462  0.02  -4.191 -0.311 -4.193], avg rr = 1.04, avg theta fixed effect = -0.0073, loss prop od=0, total trips=[5.71e+04 6.35e+04 5.72e+04 5.31e+04 5.64e+04 6.01e+04 5.79e+04 6.22e+04
#  7.11e+04 7.34e+04 7.52e+04 6.73e+04 5.38e+04 4.44e+04 3.33e+04], polynomial weights: [4.1e-01 6.0e-01 9.5e-01], kappa = [108.003  23.238 -31.658], lambda eq=1, relative gap=0.31, train equilibrium loss=2.4e+05, val equilibrium loss=2.4e+05, time: 465.1
#
# 20/20: train mse=2.3e+05, train mse traveltime=0.0015, train mdape traveltime=4.2 train mse flow=6.8e+05, train mdape flow=16.2, val mse=8.7e+05, val mse traveltime=0.17, val mdape traveltime=15.2 val mse flow=2.6e+06, val mdape flow=26.3, avg theta = [-4.421 -3.296  0.    -3.446 -0.469 -4.934], avg rr = 0.75, avg theta fixed effect = 0.013, loss prop od=0, total trips=[6.27e+04 6.51e+04 5.94e+04 5.89e+04 6.93e+04 7.52e+04 7.44e+04 8.06e+04
#  8.83e+04 9.47e+04 9.39e+04 8.90e+04 7.49e+04 7.07e+04 6.34e+04], polynomial weights: [1.8e-01 1.1e-01 2.9e-01], kappa = [108.003  23.238 -31.658], lambda eq=1, relative gap=0.044, train equilibrium loss=2.1e+04, val equilibrium loss=2.1e+04, time: 9320.8
#
# Relative gap threshold of inf was achieved in learning stage
#
# Fold 4/5
#
# Model training
#
# Pretraining generation weights
#
# period 0 -> p-values kappa: {'population': 0.0017, 'income': 0.5592, 'bus_stops': 0.341}
# period 1 -> p-values kappa: {'population': 0.0017, 'income': 0.5592, 'bus_stops': 0.341}
# period 2 -> p-values kappa: {'population': 0.0017, 'income': 0.5592, 'bus_stops': 0.341}
# period 3 -> p-values kappa: {'population': 0.0017, 'income': 0.5592, 'bus_stops': 0.341}
# period 4 -> p-values kappa: {'population': 0.0017, 'income': 0.5592, 'bus_stops': 0.341}
# period 5 -> p-values kappa: {'population': 0.0017, 'income': 0.5592, 'bus_stops': 0.341}
# period 6 -> p-values kappa: {'population': 0.0017, 'income': 0.5592, 'bus_stops': 0.341}
# period 7 -> p-values kappa: {'population': 0.0017, 'income': 0.5592, 'bus_stops': 0.341}
# period 8 -> p-values kappa: {'population': 0.0017, 'income': 0.5592, 'bus_stops': 0.341}
# period 9 -> p-values kappa: {'population': 0.0017, 'income': 0.5592, 'bus_stops': 0.341}
# period 10 -> p-values kappa: {'population': 0.0017, 'income': 0.5592, 'bus_stops': 0.341}
# period 11 -> p-values kappa: {'population': 0.0017, 'income': 0.5592, 'bus_stops': 0.341}
# period 12 -> p-values kappa: {'population': 0.0017, 'income': 0.5592, 'bus_stops': 0.341}
# period 13 -> p-values kappa: {'population': 0.0017, 'income': 0.5592, 'bus_stops': 0.341}
# period 14 -> p-values kappa: {'population': 0.0017, 'income': 0.5592, 'bus_stops': 0.341}
#
# Link flows and travel times were pretrained with single pass of traffic assignment
# Benchmark metrics using historical mean in training data to make predictions in the validation set:
#
#
#     component    value metric
# 0        flow       50  mdape
# 1  traveltime       49  mdape
# 0        flow  4.6e+06    mse
# 1  traveltime    0.057    mse
# 0        flow  1.5e+02   mape
# 1  traveltime       92   mape
# 0        flow    -0.12     r2
# 1  traveltime -0.00036     r2
#
# hyperparameters loss function: {'od': 0, 'traveltime': 1, 'flow': 1, 'equilibrium': 1.0}
#
# number of periods: 15, batch size: 1, threshold relative gap: inf
# training set -> timepoints: 195, obs [t x]: [1178.  112.], coverage [t x]: [0.488 0.047]
# validation set -> timepoints: 195, obs [t x]: [277.  28.], coverage [t x]: [0.115 0.012]
#
# Learning stage: 20 epochs
#
# 0/20: train mse=1.8e+06, train mse traveltime=0.095, train mdape traveltime=14.7 train mse flow=5.3e+06, train mdape flow=50.2, val mse=2.2e+06, val mse traveltime=0.059, val mdape traveltime=15.5 val mse flow=6.5e+06, val mdape flow=65.1, avg theta = [-3.06  -3.268  0.    -4.537  0.    -3.879], avg rr = 1.07, avg theta fixed effect = 0, loss prop od=0, total trips=[5.47e+04 6.30e+04 5.51e+04 4.96e+04 4.98e+04 5.23e+04 5.48e+04 5.82e+04
#  6.32e+04 6.65e+04 6.63e+04 5.86e+04 4.59e+04 3.63e+04 3.04e+04], polynomial weights: [1.0e+00 1.0e+00 1.0e+00], kappa = [108.003  23.238 -31.658], lambda eq=1, relative gap=0.025, train equilibrium loss=3.1e+04, val equilibrium loss=3.1e+04, time: 2.6
#
# 1/20: train mse=9.6e+05, train mse traveltime=0.0036, train mdape traveltime=7.3 train mse flow=2.6e+06, train mdape flow=28.9, val mse=1.7e+06, val mse traveltime=0.092, val mdape traveltime=14.3 val mse flow=4.8e+06, val mdape flow=62.0, avg theta = [-3.547 -3.641  0.    -4.12  -0.314 -4.19 ], avg rr = 1.03, avg theta fixed effect = -0.02, loss prop od=0, total trips=[5.88e+04 6.34e+04 5.89e+04 5.51e+04 6.15e+04 6.35e+04 6.24e+04 6.55e+04
#  6.94e+04 7.56e+04 7.72e+04 7.07e+04 5.44e+04 4.47e+04 4.00e+04], polynomial weights: [4.1e-01 4.6e-01 6.9e-01], kappa = [108.003  23.238 -31.658], lambda eq=1, relative gap=0.32, train equilibrium loss=2.9e+05, val equilibrium loss=2.9e+05, time: 488.6
#
# 20/20: train mse=2.7e+05, train mse traveltime=0.0019, train mdape traveltime=4.5 train mse flow=8e+05, train mdape flow=16.6, val mse=5.6e+05, val mse traveltime=0.05, val mdape traveltime=14.0 val mse flow=1.7e+06, val mdape flow=45.3, avg theta = [-4.691 -3.957  0.    -3.099 -0.041 -4.451], avg rr = 0.84, avg theta fixed effect = -0.013, loss prop od=0, total trips=[5.78e+04 6.68e+04 6.08e+04 6.09e+04 7.03e+04 7.57e+04 7.58e+04 8.09e+04
#  8.92e+04 9.86e+04 9.61e+04 9.14e+04 7.73e+04 7.27e+04 6.43e+04], polynomial weights: [1.7e-01 1.3e-01 1.7e-01], kappa = [108.003  23.238 -31.658], lambda eq=1, relative gap=0.052, train equilibrium loss=2.1e+04, val equilibrium loss=2.1e+04, time: 9229.3
#
# Relative gap threshold of inf was achieved in learning stage
#
# Fold 5/5
#
# Model training
#
# Pretraining generation weights
#
# period 0 -> p-values kappa: {'population': 0.0017, 'income': 0.5592, 'bus_stops': 0.341}
# period 1 -> p-values kappa: {'population': 0.0017, 'income': 0.5592, 'bus_stops': 0.341}
# period 2 -> p-values kappa: {'population': 0.0017, 'income': 0.5592, 'bus_stops': 0.341}
# period 3 -> p-values kappa: {'population': 0.0017, 'income': 0.5592, 'bus_stops': 0.341}
# period 4 -> p-values kappa: {'population': 0.0017, 'income': 0.5592, 'bus_stops': 0.341}
# period 5 -> p-values kappa: {'population': 0.0017, 'income': 0.5592, 'bus_stops': 0.341}
# period 6 -> p-values kappa: {'population': 0.0017, 'income': 0.5592, 'bus_stops': 0.341}
# period 7 -> p-values kappa: {'population': 0.0017, 'income': 0.5592, 'bus_stops': 0.341}
# period 8 -> p-values kappa: {'population': 0.0017, 'income': 0.5592, 'bus_stops': 0.341}
# period 9 -> p-values kappa: {'population': 0.0017, 'income': 0.5592, 'bus_stops': 0.341}
# period 10 -> p-values kappa: {'population': 0.0017, 'income': 0.5592, 'bus_stops': 0.341}
# period 11 -> p-values kappa: {'population': 0.0017, 'income': 0.5592, 'bus_stops': 0.341}
# period 12 -> p-values kappa: {'population': 0.0017, 'income': 0.5592, 'bus_stops': 0.341}
# period 13 -> p-values kappa: {'population': 0.0017, 'income': 0.5592, 'bus_stops': 0.341}
# period 14 -> p-values kappa: {'population': 0.0017, 'income': 0.5592, 'bus_stops': 0.341}
#
# Link flows and travel times were pretrained with single pass of traffic assignment
# Benchmark metrics using historical mean in training data to make predictions in the validation set:
#
#
#     component   value metric
# 0        flow      42  mdape
# 1  traveltime      49  mdape
# 0        flow 4.4e+06    mse
# 1  traveltime   0.064    mse
# 0        flow      92   mape
# 1  traveltime      79   mape
# 0        flow  -0.024     r2
# 1  traveltime -0.0019     r2
#
# hyperparameters loss function: {'od': 0, 'traveltime': 1, 'flow': 1, 'equilibrium': 1.0}
#
# number of periods: 15, batch size: 1, threshold relative gap: inf
# training set -> timepoints: 195, obs [t x]: [1165.  112.], coverage [t x]: [0.483 0.047]
# validation set -> timepoints: 195, obs [t x]: [289.  28.], coverage [t x]: [0.12  0.012]
#
# Learning stage: 20 epochs
#
# 0/20: train mse=1.9e+06, train mse traveltime=0.083, train mdape traveltime=15.0 train mse flow=5.6e+06, train mdape flow=53.0, val mse=1.8e+06, val mse traveltime=0.11, val mdape traveltime=14.0 val mse flow=5.3e+06, val mdape flow=47.6, avg theta = [-3.06  -3.268  0.    -4.537  0.    -3.879], avg rr = 1.07, avg theta fixed effect = 0, loss prop od=0, total trips=[5.47e+04 6.30e+04 5.51e+04 4.96e+04 4.98e+04 5.23e+04 5.48e+04 5.82e+04
#  6.32e+04 6.65e+04 6.63e+04 5.86e+04 4.59e+04 3.63e+04 3.04e+04], polynomial weights: [1.0e+00 1.0e+00 1.0e+00], kappa = [108.003  23.238 -31.658], lambda eq=1, relative gap=0.025, train equilibrium loss=3.1e+04, val equilibrium loss=3.1e+04, time: 2.6
#
# 1/20: train mse=1.1e+06, train mse traveltime=0.0026, train mdape traveltime=7.3 train mse flow=3e+06, train mdape flow=30.2, val mse=1e+06, val mse traveltime=0.19, val mdape traveltime=12.6 val mse flow=2.8e+06, val mdape flow=35.8, avg theta = [-3.485 -3.402  0.    -3.997 -0.151 -4.102], avg rr = 0.98, avg theta fixed effect = -0.03, loss prop od=0, total trips=[5.90e+04 6.41e+04 5.72e+04 5.42e+04 5.65e+04 6.08e+04 6.35e+04 6.56e+04
#  7.28e+04 7.57e+04 7.40e+04 6.87e+04 5.38e+04 4.49e+04 3.84e+04], polynomial weights: [4.0e-01 2.6e-01 2.6e-01], kappa = [108.003  23.238 -31.658], lambda eq=1, relative gap=0.29, train equilibrium loss=2.3e+05, val equilibrium loss=2.3e+05, time: 479.7
#
# 20/20: train mse=2.7e+05, train mse traveltime=0.0013, train mdape traveltime=4.1 train mse flow=8e+05, train mdape flow=16.9, val mse=4.4e+05, val mse traveltime=0.06, val mdape traveltime=13.7 val mse flow=1.3e+06, val mdape flow=21.8, avg theta = [-3.387 -2.883  0.    -4.067  0.    -4.135], avg rr = 0.85, avg theta fixed effect = -0.032, loss prop od=0, total trips=[6.31e+04 6.77e+04 6.07e+04 5.86e+04 6.97e+04 7.47e+04 7.58e+04 8.01e+04
#  9.16e+04 9.61e+04 9.43e+04 9.02e+04 7.57e+04 7.26e+04 6.74e+04], polynomial weights: [1.4e-01 1.4e-01 9.4e-02], kappa = [108.003  23.238 -31.658], lambda eq=1, relative gap=0.047, train equilibrium loss=1.4e+04, val equilibrium loss=1.4e+04, time: 9614.0
#
# Relative gap threshold of inf was achieved in learning stage

# %%
filename = f"{ts}_kfold_{network.key}.csv"
metrics_kfold_df['MaTE'].to_csv(f"./output/tables/{filename}")
print(f"File {filename} written with k-fold results for TVGODULPE model")

with pd.option_context('display.float_format', '{:0.3g}'.format):
    print(metrics_kfold_df['MaTE'][metrics_kfold_df['MaTE'].component.isin(['flow','traveltime'])].\
          groupby(['dataset', 'component', 'metric', 'stage'])['value'].\
          aggregate(['median', 'mean', 'std']))
# Out:
# File 240127231842_kfold_fresno.csv written with k-fold results for TVGODULPE model
#                                                median     mean      std
# dataset    component  metric stage
# training   flow       mape   final               30.7     29.2     3.75
#                              historical mean     89.7     90.5     6.59
#                              initial             59.6     60.7     1.94
#                       mdape  final               16.2     15.6     1.42
#                              historical mean     38.2     38.6     1.72
#                              initial             52.2     51.6     1.81
#                       mse    final            6.8e+05 7.21e+05 7.62e+04
#                              historical mean 3.58e+06  3.5e+06  2.1e+05
#                              initial         5.54e+06 5.57e+06 2.26e+05
#                       r2     final              0.811    0.792   0.0343
#                              historical mean 1.57e-09 3.34e-09 4.28e-09
#                              initial           -0.627   -0.594   0.0984
#            traveltime mape   final               6.08     6.17     0.25
#                              historical mean       84     83.6    0.945
#                              initial             32.1     31.9    0.989
#                       mdape  final               4.27     4.29    0.155
#                              historical mean     50.2     50.3    0.457
#                              initial             14.7     14.8    0.177
#                       mse    final            0.00147  0.00148 0.000284
#                              historical mean   0.0657   0.0641  0.00447
#                              initial            0.085   0.0883   0.0099
#                       r2     final              0.978    0.977  0.00357
#                              historical mean 3.75e-08  2.5e-08 2.37e-08
#                              initial           -0.294   -0.392    0.253
# validation flow       mape   final                 43     52.2     21.2
#                              historical mean     92.1     92.4     40.2
#                              initial             65.1     60.7     7.75
#                       mdape  final                 32     32.7     9.33
#                              historical mean     40.5       40     6.75
#                              initial             49.6     52.9     8.56
#                       mse    final           2.22e+06 2.05e+06  5.5e+05
#                              historical mean 3.34e+06  3.6e+06 8.67e+05
#                              initial         5.67e+06 5.58e+06 8.93e+05
#                       r2     final              0.254    0.336    0.296
#                              historical mean  -0.0263  -0.0678   0.0732
#                              initial           -0.578   -0.721    0.461
#            traveltime mape   final               30.8     30.8     9.79
#                              historical mean     81.5     83.7     6.37
#                              initial               31     31.9     3.91
#                       mdape  final                 14     13.8      1.3
#                              historical mean     50.3     50.3     1.47
#                              initial             15.2     14.8    0.747
#                       mse    final             0.0605   0.0964   0.0722
#                              historical mean    0.057   0.0643    0.018
#                              initial            0.102   0.0876   0.0396
#                       r2     final             0.0528   -0.454     1.05
#                              historical mean  -0.0019 -0.00213  0.00238
#                              initial            -0.73   -0.523    0.855

# %%
fig, axs = plot_metrics_kfold(df = metrics_kfold_df['MaTE'][metrics_kfold_df['MaTE'].component.isin(['flow','traveltime'])], model_name = 'MaTE', metric_name = _EVALUATION_METRIC.__name__, showfliers = True)

for ax in axs.reshape(-1):
    ax.set_ylim(bottom = 0)

plt.savefig(f'output/figures/results/fresno-kfold-{_EVALUATION_METRIC.__name__}-mate.png', dpi = 300)

plt.show()

# %%
parameters_kfold_df['MaTE']['hour'] = parameters_kfold_df['MaTE'].period.replace({v: k for k, v in models_kfold['MaTE'].period_dict.items()}). \
    replace(dict(zip(period_keys.period_id, period_keys.hour)))

parameters_kfold_df['MaTE']['parameter'] = parameters_kfold_df['MaTE']['parameter'].\
    replace({'tt': 'travel time', 'median_inc': 'income', 'tt_sd': 'std. travel time', 'bus_stops': 'bus stops', 'vot': 'reliability ratio'})

parameters_kfold_df['MaTE']['hour'] \
    = parameters_kfold_df['MaTE']['period'].map({v:period_keys[period_keys.period_id == k]['hour'].iloc[0] for k,v in models_kfold['MaTE'].period_dict.items()})

parameters_kfold_df['MaTE'] = parameters_kfold_df['MaTE'][parameters_kfold_df['MaTE'].parameter != 'reliability ratio']

fig, axs = plot_parameters_kfold(df = parameters_kfold_df['MaTE'][parameters_kfold_df['MaTE'].group == 'utility'], n_cols_legend = 2, figsize = (5.5,5.5), hour_label = True, rotation_xticks=90)

plt.axhline(0, linestyle ='dashed', color = 'black')

plt.savefig('output/figures/results/fresno-kfold-utility-periods-mate.png', dpi = 300)

plt.show()

fig, axs = plot_parameters_kfold(df = parameters_kfold_df['MaTE'][parameters_kfold_df['MaTE'].group == 'generation'], n_cols_legend = 3, figsize = (5.5,5.5), hour_label = True, rotation_xticks=90)

plt.axhline(0, linestyle ='dashed', color = 'black')

plt.savefig('output/figures/results/fresno-kfold-generation-periods-mate.png', dpi = 300)

plt.show()

# %% [markdown]
# ### - Baselines

# %%
# Calculate centroids of links to compute baselines models
links_gdf['X'] = links_gdf.to_crs(2228).geometry.centroid.to_crs(4326).x
links_gdf['Y'] = links_gdf.to_crs(2228).geometry.centroid.to_crs(4326).y
coordinates = links_gdf[['X', 'Y']].values

# %%
# Baselines are computed for every sample
metrics_kfold_df['baselines'] = pd.DataFrame({})
n_samples = XT_val.shape[0]

t0 = time.time()
for i in range(n_samples):

    isl.printer.printIterationBar(i+1, n_samples, prefix='Sample:',length=20)

    metrics_kfold_df['baselines'] = pd.concat([metrics_kfold_df['baselines'],
                                  compute_baseline_predictions_kfold(
                                      metric=_EVALUATION_METRIC,
                                      X = XT_val[i],
                                      y = YT_val[i][:,0][tf.newaxis,:],
                                      coordinates = coordinates,
                                      n_splits = _N_SPLITS, seed = _SEED).assign(component = 'traveltime')])

    metrics_kfold_df['baselines'] = pd.concat([metrics_kfold_df['baselines'],
                                  compute_baseline_predictions_kfold(
                                      metric=_EVALUATION_METRIC,
                                      X = XT_val[i],
                                      y = YT_val[i][:,1][tf.newaxis,:],
                                      coordinates = coordinates,
                                      n_splits = _N_SPLITS, seed = _SEED).assign(component = 'flow')])

    metrics_kfold_df['baselines']['sample'] = i

print(f'runtime: {time.time()-t0:0.1f} [s]')
# Out:
# Sample: |####################| 195/195
# runtime: 478.3 [s]

# %%
metrics_kfold_df['baselines'].to_csv(f"./output/experiments/{ts}_kfold_baselines_{network.key}.csv")

# %% [markdown]
# ### Comparison between our model and benchmarks

# %%
metrics_kfold_plot_df = metrics_kfold_df['MaTE'][
        (metrics_kfold_df['MaTE'].component != 'equilibrium') & (metrics_kfold_df['MaTE'].metric == _EVALUATION_METRIC.__name__) &
        (metrics_kfold_df['MaTE'].dataset == 'validation') & (metrics_kfold_df['MaTE'].stage == 'final')].\
        assign(model = 'MaTE')

# %%
metrics_kfold_df['baselines'] \
    = metrics_kfold_df['baselines'].groupby(['fold', 'model', 'component'])[['value']].mean().reset_index()

metrics_kfold_plot_df = pd.concat([metrics_kfold_df['baselines'][['model','component','value']],
                                   metrics_kfold_plot_df[['model','component','value']]])

metrics_kfold_plot_df.loc[metrics_kfold_plot_df.model == 'MaTE', 'model'] = 'our model'

metrics_kfold_plot_df.to_csv(f"./output/tables/{ts}_kfold_{network.key}_all.csv")

# %%
means_mapes = metrics_kfold_plot_df.groupby(['component','model'])['value'].mean().reset_index().rename(columns={'value':'mean'})
se_mapes = metrics_kfold_plot_df.groupby(['component','model'])['value'].agg(['std', 'count']).apply(lambda row: row['std'] / np.sqrt(row['count']), axis=1).reset_index().rename(columns={0:'se'})

pd.merge(means_mapes, se_mapes).sort_values(by = ['component', 'mean'])
# Out:
#     component               model          mean            se
# 4        flow           our model  3.272116e+01  4.174201e+00
# 3        flow    ordinary_kriging  3.470143e+01  1.203276e+00
# 0        flow     historical_mean  3.478421e+01  1.235485e+00
# 1        flow  kriging_regression  3.575839e+01  2.684224e+00
# 2        flow   linear_regression  3.779993e+01  1.315640e+00
# 9  traveltime           our model  1.380994e+01  5.792801e-01
# 6  traveltime  kriging_regression  2.502437e+01  4.268838e-01
# 5  traveltime     historical_mean  3.983391e+01  6.525342e-01
# 7  traveltime   linear_regression  4.022668e+01  6.611708e-01
# 8  traveltime    ordinary_kriging  2.382936e+15  2.378092e+15

# %%
# Note: Result from ordinary kriging are removed due to unstable estimates and extremely large values of evaluation metric for travel time
fig, _ = plot_baselines_kfold(df = metrics_kfold_plot_df.
                     assign(model = metrics_kfold_plot_df.model.replace('_', ' ', regex=True)).replace('our model', 'MaTE', regex=True)\
                        [metrics_kfold_plot_df.model != 'ordinary_kriging'],
                     metric_name=_EVALUATION_METRIC.__name__, sharex=True, sharey=True, showfliers = False)

fig.savefig(f'output/figures/results/fresno-kfold-{_EVALUATION_METRIC.__name__}-baselines-mate.png', dpi=300)

# %% [markdown]
# ### Predicted traffic congestion

# %%
# Link-level spatial information
links_gdf['link_key'] = pd.Categorical(links_gdf['key'].apply(ast.literal_eval), list(network.links_dict.keys()))

# Create dataframe with data collected in 2020 during peak hours only
model_df = df[(df.hour.isin(_HOURS)) & (df['year']==2020)].sort_values(['period','link_key'])
# links_gdf = links_gdf.sort_values(['link_key'])

# Build dataset witg data collected between 4-5pm in the first Tuesdays of Oct 2019 and 2020
benchmark_df = df[(df.hour == 16) & df['date'].isin(['2019-10-01', '2020-10-06'])].sort_values(['period','link_key'])

fig_speed, fig_flow = plot_congestion_maps(model=inference_models['MaTE'], model_df=model_df, benchmark_df = benchmark_df,
                     gdf=links_gdf.sort_values(['link_key']), features=_FEATURES_Z, cmap = 'viridis', benchmark_model = 'regression_kriging')
# Out:
# /Users/pablo/miniforge3/envs/mate/lib/python3.10/site-packages/mapclassify/classifiers.py:939: RuntimeWarning: invalid value encountered in subtract
#   css = yc - yc.mean()
# /Users/pablo/miniforge3/envs/mate/lib/python3.10/site-packages/mapclassify/classifiers.py:969: RuntimeWarning: invalid value encountered in double_scalars
#   gadf = 1 if adam == 0 else 1 - self.adcm / adam

# %%
fig_flow.savefig('output/figures/results/fresno-map-flow-mate.png', dpi=300)
fig_flow

# %%
fig_speed.savefig('output/figures/results/fresno-map-speed-mate.png', dpi=300)
fig_speed

# %% [markdown]
# ## Global runtime

# %%
print(f'runtime: {time.time()-t0_global:0.1f} [s]')
# Out:
# runtime: 50405.8 [s]
